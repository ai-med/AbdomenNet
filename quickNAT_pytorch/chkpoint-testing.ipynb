# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

from utils.log_utils import LogWriter
import torch
import glob
from quick_oct import QuickOct as mclass
import utils.common_utils as common_utils
import inspect
import shutil
from utils.evaluator import evaluate, evaluate2view, evaluate_dice_score, compute_vol_bulk, evaluate3view
from settings import Settings

# %%
def evaluate(eval_params, net_params, data_params, common_params, train_params, model_chkpt):
    eval_model_path = eval_params['eval_model_path']
    num_classes = net_params['num_class']
    labels = data_params['labels']
    data_dir = eval_params['data_dir']
    label_dir = eval_params['label_dir']
    volumes_txt_file = eval_params['volumes_txt_file']
    remap_config = eval_params['remap_config']
    device = common_params['device']
    log_dir = common_params['log_dir']
    exp_dir = common_params['exp_dir']
    exp_name = train_params['exp_name']
    save_predictions_dir = eval_params['save_predictions_dir']
    prediction_path = os.path.join(exp_dir, exp_name, save_predictions_dir)
    orientation = eval_params['orientation']
    data_id = eval_params['data_id']
    multi_channel = data_params['use_3channel']
    use_2channel = data_params['use_2channel']
    logWriter = LogWriter(num_classes, log_dir, exp_name, labels=labels)
    print("######################################################################################")
    print(model_chkpt)
    
    model = mclass(net_params)
    cp = torch.load(model_chkpt)
    model.load_state_dict(cp['state_dict'])
    avg_dice_score, class_dist = evaluate_dice_score(model,
                                                        num_classes,
                                                        data_dir,
                                                        label_dir,
                                                        volumes_txt_file,
                                                        remap_config,
                                                        orientation,
                                                        prediction_path,
                                                        data_id,
                                                        device,
                                                        logWriter,
                                                        multi_channel=multi_channel,
                                                        use_2channel=use_2channel)
    logWriter.close()
    print("######################################################################################")

    
def evaluate_save_best(eval_params, net_params, data_params, common_params, train_params, model_chkpt):
    eval_model_path = eval_params['eval_model_path']
    num_classes = net_params['num_class']
    labels = data_params['labels']
    data_dir = eval_params['data_dir']
    label_dir = eval_params['label_dir']
    volumes_txt_file = eval_params['volumes_txt_file']
    remap_config = eval_params['remap_config']
    device = common_params['device']
    log_dir = common_params['log_dir']
    exp_dir = common_params['exp_dir']
    exp_name = train_params['exp_name']
    save_predictions_dir = eval_params['save_predictions_dir']
    prediction_path = os.path.join(exp_dir, exp_name, save_predictions_dir)
    orientation = eval_params['orientation']
    data_id = eval_params['data_id']
    multi_channel = data_params['use_3channel']
    use_2channel = data_params['use_2channel']
    logWriter = LogWriter(num_classes, log_dir, exp_name, labels=labels)
    print("######################################################################################")
    print(model_chkpt)
    arch_file_path = inspect.getfile(mclass)
    model = mclass(net_params)
#     print(inspect.getfile(inspect.getfile(model)))
    cp = torch.load(model_chkpt)
    model.load_state_dict(cp['state_dict'])
    avg_dice_score, class_dist = evaluate_dice_score(model,
                                                        num_classes,
                                                        data_dir,
                                                        label_dir,
                                                        volumes_txt_file,
                                                        remap_config,
                                                        orientation,
                                                        prediction_path,
                                                        data_id,
                                                        device,
                                                        logWriter,
                                                        multi_channel=multi_channel,
                                                        use_2channel=use_2channel)
    logWriter.close()
    exp_dir_path = os.path.join(exp_dir, exp_name)
    save_architectural_files(exp_dir_path, arch_file_path)
    best_model_path = os.path.join(common_params['save_model_dir'], train_params['final_model_file'])
    torch.save(model, best_model_path)
    print("######################################################################################")
    
def save_architectural_files(exp_dir_path, arch_file_path):
    ARCHITECTURE_DIR = 'architecture'
    if arch_file_path is not None:
        destination = os.path.join(exp_dir_path, ARCHITECTURE_DIR)
        common_utils.create_if_not(destination)
        arch_base = "/".join(arch_file_path.split('/')[:-1])
        print(arch_file_path, arch_base, destination+'/model.py')
        shutil.copy(arch_file_path, destination+'/model.py')
        shutil.copy(f'{arch_base}/run.py', f'{destination}/run.py')
        shutil.copy(f'{arch_base}/solver.py', f'{destination}/solver.py')
        shutil.copy(f'{arch_base}/utils/evaluator.py', f'{destination}/utils-evaluator.py')
        shutil.copy(f'{arch_base}/nn_common_modules/losses.py', f'{destination}/nn_common_modules-losses.py')
        shutil.copy(f'{arch_base}/nn_common_modules/modules.py', f'{destination}/nn_common_modules-modules.py')
        shutil.copy(f'{arch_base}/settings_merged_jj.ini', f'{destination}/settings_merged_jj.ini')
    else:
        print('No Architectural file!!!')

# %%
model_path = "/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/*"
chkpts = glob.glob(model_path)
for ch in chkpts:
    try: 
        settings = Settings('/home/abhijit/Jyotirmay/abdominal_segmentation/quickNAT_pytorch/settings_merged_jj.ini')
        common_params, data_params, net_params, train_params, eval_params = settings['COMMON'], settings['DATA'], \
                                                                        settings[
                                                                            'NETWORK'], settings['TRAINING'], \
                                                                        settings['EVAL']
        evaluate(eval_params, net_params, data_params, common_params, train_params, ch)
    except Exception as e:
        print(e)
        continue
# Out:
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_1.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.0871981
# Mean dice score without background:  0.010007762
# all dice scores:  [[0.7830899  0.10249846 0.         0.         0.         0.
#   0.         0.         0.        ]
#  [0.6263517  0.05762573 0.         0.         0.         0.
#   0.         0.         0.        ]]
# class wise mean dice scores:  [0.7047208 0.0800621 0.        0.        0.        0.        0.
#  0.        0.       ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_2.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.16863674
# Mean dice score without background:  0.0678402
# all dice scores:  [[0.96586573 0.31580272 0.         0.         0.         0.
#   0.         0.         0.        ]
#  [0.98415244 0.7696405  0.         0.         0.         0.
#   0.         0.         0.        ]]
# class wise mean dice scores:  [0.9750091 0.5427216 0.        0.        0.        0.        0.
#  0.        0.       ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_3.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.19149195
# Mean dice score without background:  0.092816345
# all dice scores:  [[0.9757501  0.6556834  0.         0.         0.         0.
#   0.         0.         0.        ]
#  [0.98604363 0.8293781  0.         0.         0.         0.
#   0.         0.         0.        ]]
# class wise mean dice scores:  [0.98089683 0.74253076 0.         0.         0.         0.
#  0.         0.         0.        ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_4.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.19546328
# Mean dice score without background:  0.097110786
# all dice scores:  [[9.7869742e-01 7.3551917e-01 1.8370434e-03 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00]
#  [9.8586905e-01 8.1594044e-01 4.7600159e-04 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00]]
# class wise mean dice scores:  [0.98228323 0.7757298  0.00115652 0.         0.         0.
#  0.         0.         0.        ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_5.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.24686241
# Mean dice score without background:  0.15528603
# all dice scores:  [[0.9756822  0.74472    0.45523405 0.03185915 0.         0.
#   0.0058997  0.         0.        ]
#  [0.9832646  0.7674555  0.46245664 0.01695142 0.         0.
#   0.         0.         0.        ]]
# class wise mean dice scores:  [0.9794734  0.7560878  0.45884535 0.02440528 0.         0.
#  0.00294985 0.         0.        ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_6.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.24947323
# Mean dice score without background:  0.15763566
# all dice scores:  [[0.97950345 0.71851397 0.4554288  0.00251847 0.         0.
#   0.         0.         0.        ]
#  [0.9888441  0.8419826  0.4563302  0.04739632 0.         0.
#   0.         0.         0.        ]]
# class wise mean dice scores:  [0.9841738  0.7802483  0.4558795  0.02495739 0.         0.
#  0.         0.         0.        ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_7.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.205053
# Mean dice score without background:  0.10734004
# all dice scores:  [[0.9829969  0.8037588  0.         0.         0.         0.
#   0.         0.         0.        ]
#  [0.99051654 0.9136818  0.         0.         0.         0.
#   0.         0.         0.        ]]
# class wise mean dice scores:  [0.9867567 0.8587203 0.        0.        0.        0.        0.
#  0.        0.       ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_8.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.1891827
# Mean dice score without background:  0.090141326
# all dice scores:  [[0.97340226 0.5285579  0.         0.         0.         0.
#   0.         0.         0.        ]
#  [0.989625   0.9137034  0.         0.         0.         0.
#   0.         0.         0.        ]]
# class wise mean dice scores:  [0.9815136 0.7211306 0.        0.        0.        0.        0.
#  0.        0.       ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_9.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.20011882
# Mean dice score without background:  0.10201178
# all dice scores:  [[0.9801699  0.72768253 0.         0.         0.         0.
#   0.         0.         0.        ]
#  [0.98978037 0.9045059  0.         0.         0.         0.
#   0.         0.         0.        ]]
# class wise mean dice scores:  [0.9849751 0.8160942 0.        0.        0.        0.        0.
#  0.        0.       ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_10.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.18742569
# Mean dice score without background:  0.0882202
# all dice scores:  [[0.97250503 0.49129042 0.         0.         0.         0.
#   0.         0.         0.        ]
#  [0.9896342  0.91833    0.0019028  0.         0.         0.
#   0.         0.         0.        ]]
# class wise mean dice scores:  [9.810696e-01 7.048102e-01 9.513993e-04 0.000000e+00 0.000000e+00
#  0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_11.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.28341752
# Mean dice score without background:  0.19530596
# all dice scores:  [[0.9851132  0.81895125 0.7251129  0.         0.         0.
#   0.         0.         0.        ]
#  [0.9915067  0.9265465  0.6542847  0.         0.         0.
#   0.         0.         0.        ]]
# class wise mean dice scores:  [0.98831    0.87274885 0.6896988  0.         0.         0.
#  0.         0.         0.        ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_12.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.27909803
# Mean dice score without background:  0.19071417
# all dice scores:  [[0.9816819  0.7561032  0.32536831 0.00216685 0.         0.
#   0.         0.         0.        ]
#  [0.99065614 0.8982557  0.8406482  0.22888444 0.         0.
#   0.         0.         0.        ]]
# class wise mean dice scores:  [0.986169   0.82717943 0.5830082  0.11552565 0.         0.
#  0.         0.         0.        ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_13.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.31698787
# Mean dice score without background:  0.23331918
# all dice scores:  [[0.9861283  0.84171474 0.5766081  0.57971907 0.         0.
#   0.         0.         0.        ]
#  [0.9865466  0.9027554  0.42496917 0.40734026 0.         0.
#   0.         0.         0.        ]]
# class wise mean dice scores:  [0.9863374  0.87223506 0.5007886  0.49352968 0.         0.
#  0.         0.         0.        ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_14.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.3306912
# Mean dice score without background:  0.24862951
# all dice scores:  [[0.9827417  0.7592481  0.52138495 0.49729    0.         0.
#   0.         0.         0.        ]
#  [0.99162704 0.91375387 0.48503426 0.801361   0.         0.
#   0.         0.         0.        ]]
# class wise mean dice scores:  [0.9871844 0.836501  0.5032096 0.6493255 0.        0.        0.
#  0.        0.       ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_15.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.359055
# Mean dice score without background:  0.2802977
# all dice scores:  [[0.98737603 0.8555545  0.7222737  0.77703655 0.         0.
#   0.         0.         0.        ]
#  [0.9908514  0.9056167  0.50222266 0.72205865 0.         0.
#   0.         0.         0.        ]]
# class wise mean dice scores:  [0.9891137 0.8805856 0.6122482 0.7495476 0.        0.        0.
#  0.        0.       ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_16.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.36550766
# Mean dice score without background:  0.2875493
# all dice scores:  [[0.9870976  0.86765933 0.72590137 0.71869093 0.         0.
#   0.         0.         0.00325733]
#  [0.9912514  0.90810835 0.59567815 0.7367103  0.         0.
#   0.         0.         0.0447828 ]]
# class wise mean dice scores:  [0.9891745  0.88788384 0.6607897  0.7277006  0.         0.
#  0.         0.         0.02402006]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_17.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.3825254
# Mean dice score without background:  0.30659312
# all dice scores:  [[0.98752105 0.8534485  0.78326154 0.7752974  0.         0.
#   0.         0.         0.0080064 ]
#  [0.99244684 0.931413   0.7411489  0.7776994  0.         0.
#   0.         0.         0.03521445]]
# class wise mean dice scores:  [0.9899839  0.8924308  0.76220524 0.77649844 0.         0.
#  0.         0.         0.02161043]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_18.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.3906105
# Mean dice score without background:  0.31601217
# all dice scores:  [[0.98215663 0.6705324  0.8079422  0.5082272  0.         0.
#   0.         0.         0.20185114]
#  [0.9926373  0.9152305  0.8430268  0.8104199  0.         0.
#   0.         0.         0.2989647 ]]
# class wise mean dice scores:  [0.98739696 0.7928815  0.8254845  0.6593236  0.         0.
#  0.         0.         0.25040793]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_19.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0
pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.72451264
# Mean dice score without background:  0.69105864
# all dice scores:  [[0.9886256  0.8467707  0.8127446  0.88271356 0.8493704  0.27515396
#   0.08571426 0.41434518 0.5274262 ]
#  [0.9956647  0.9512264  0.86635715 0.9179325  0.88839954 0.7279548
#   0.6277371  0.613682   0.76940906]]
# class wise mean dice scores:  [0.9921452  0.89899856 0.83955085 0.90032303 0.868885   0.50155437
#  0.3567257  0.5140136  0.6484176 ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_34.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.6783588
# Mean dice score without background:  0.6392633
# all dice scores:  [[0.9863711  0.7946261  0.7674808  0.87607473 0.8612022  0.35227266
#   0.045977   0.32934928 0.07572684]
#  [0.9958747  0.9456792  0.88939834 0.9025271  0.89375186 0.64876944
#   0.5730336  0.6226621  0.6496815 ]]
# class wise mean dice scores:  [0.9911229  0.87015265 0.8284396  0.88930094 0.87747705 0.50052106
#  0.30950528 0.4760057  0.36270416]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_35.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.7182873
# Mean dice score without background:  0.6840919
# all dice scores:  [[0.9878222  0.8338264  0.8231968  0.8501939  0.84161067 0.38906744
#   0.13068178 0.3909562  0.40586793]
#  [0.9958784  0.9504985  0.9328727  0.89093226 0.91324264 0.68421036
#   0.60030615 0.6185121  0.6894951 ]]
# class wise mean dice scores:  [0.99185026 0.89216244 0.8780348  0.8705631  0.8774266  0.5366389
#  0.36549395 0.50473416 0.5476815 ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_36.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.71143097
# Mean dice score without background:  0.6764848
# all dice scores:  [[0.9865319  0.8060019  0.81555367 0.8547845  0.8068075  0.24163567
#   0.41584152 0.47961518 0.27740058]
#  [0.9954686  0.9529527  0.9140669  0.8990814  0.9052428  0.6818922
#   0.49139574 0.5326402  0.7488444 ]]
# class wise mean dice scores:  [0.9910003  0.87947726 0.8648103  0.876933   0.85602516 0.46176395
#  0.45361865 0.5061277  0.5131225 ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_37.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.67130995
# Mean dice score without background:  0.63137794
# all dice scores:  [[0.9871357  0.8504827  0.8009096  0.85944855 0.8111961  0.19913419
#   0.18307267 0.34429187 0.3894885 ]
#  [0.9943967  0.95083475 0.9153316  0.85635585 0.9032128  0.58419234
#   0.19133449 0.52756006 0.735201  ]]
# class wise mean dice scores:  [0.99076617 0.9006587  0.85812056 0.85790217 0.85720444 0.39166325
#  0.18720359 0.43592596 0.56234473]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_38.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.71274537
# Mean dice score without background:  0.6778229
# all dice scores:  [[0.9883725  0.8409255  0.7888649  0.87203646 0.8622934  0.23146471
#   0.31208786 0.43326414 0.36347032]
#  [0.995877   0.9513787  0.92956007 0.9152587  0.91071486 0.66666657
#   0.46869403 0.5772492  0.7212367 ]]
# class wise mean dice scores:  [0.9921248  0.89615214 0.8592125  0.89364755 0.8865042  0.44906563
#  0.39039093 0.50525665 0.5423535 ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_39.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.6828756
# Mean dice score without background:  0.6441882
# all dice scores:  [[0.9890552  0.857916   0.7914088  0.8644377  0.89609855 0.22664358
#   0.3848238  0.22190747 0.11695215]
#  [0.99569404 0.9495547  0.920757   0.90358317 0.90762824 0.6614172
#   0.32230905 0.57228506 0.709289  ]]
# class wise mean dice scores:  [0.99237466 0.90373534 0.8560829  0.88401043 0.9018634  0.44403037
#  0.3535664  0.39709628 0.41312057]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_40.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.69745904
# Mean dice score without background:  0.6606188
# all dice scores:  [[0.9882303  0.834605   0.80540806 0.8720845  0.891897   0.25757572
#   0.2793791  0.21321125 0.16906945]
#  [0.9961316  0.951375   0.9258998  0.9214653  0.87624544 0.652591
#   0.55180436 0.6371784  0.73011076]]
# class wise mean dice scores:  [0.99218094 0.89299    0.86565393 0.8967749  0.88407123 0.45508337
#  0.41559172 0.42519483 0.44959012]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_41.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.7339895
# Mean dice score without background:  0.70174116
# all dice scores:  [[0.9883101  0.84133565 0.81278026 0.8769652  0.8390139  0.25092933
#   0.48392546 0.5462653  0.39458612]
#  [0.9956429  0.9521859  0.9237126  0.9122796  0.9206923  0.64714074
#   0.4254658  0.63455313 0.76602715]]
# class wise mean dice scores:  [0.9919765  0.8967608  0.86824644 0.89462245 0.8798531  0.44903505
#  0.45469564 0.5904092  0.58030665]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_42.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.73653865
# Mean dice score without background:  0.7045951
# all dice scores:  [[0.9878917  0.82508653 0.8199855  0.89751214 0.8812044  0.3291492
#   0.00888888 0.44964823 0.46389624]
#  [0.99628067 0.95214677 0.93234086 0.9246587  0.9219496  0.6921674
#   0.66347677 0.69725484 0.81415534]]
# class wise mean dice scores:  [0.9920862  0.8886167  0.8761632  0.9110854  0.901577   0.51065826
#  0.33618283 0.5734515  0.6390258 ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_43.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.70054513
# Mean dice score without background:  0.66440237
# all dice scores:  [[0.98334557 0.7263224  0.8067754  0.88031554 0.8408406  0.32888883
#   0.00896861 0.3302854  0.30861124]
#  [0.9960289  0.94812703 0.9362199  0.8900573  0.9211354  0.7569572
#   0.5772726  0.61109406 0.75856614]]
# class wise mean dice scores:  [0.9896872  0.8372247  0.87149763 0.88518643 0.880988   0.542923
#  0.2931206  0.4706897  0.5335887 ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_44.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.72156435
# Mean dice score without background:  0.6876657
# all dice scores:  [[0.98982674 0.8774641  0.8174448  0.87515223 0.8892608  0.39344254
#   0.23134321 0.48467922 0.07343749]
#  [0.9956798  0.94501245 0.9340495  0.8861324  0.9197677  0.7046262
#   0.62992114 0.68034047 0.66057664]]
# class wise mean dice scores:  [0.99275327 0.9112383  0.87574714 0.8806423  0.90451425 0.54903436
#  0.43063217 0.5825099  0.36700708]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_45.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']
# evaluator here
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2460408.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2460408.nii.gz']
# evaluator here
# Mean dice score:  0.6756705
# Mean dice score without background:  0.63632554
# all dice scores:  [[0.9871489  0.8627713  0.80163854 0.84876126 0.57460654 0.16147634
#   0.3194192  0.5436937  0.4255319 ]
#  [0.99371386 0.92680806 0.9069261  0.8709687  0.7956825  0.48808166
#   0.21984975 0.6728441  0.7621483 ]]
# class wise mean dice scores:  [0.99043137 0.8947897  0.8542823  0.85986495 0.68514454 0.324779
#  0.2696345  0.6082689  0.5938401 ]
# ######################################################################################
# ######################################################################################
# /mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/checkpoint_epoch_46.pth.tar
# NUMBER OF CHANNEL 1
# CSSE
# False
# CSSE
# False
# CSSE
# False
# CSSE
# True
# CSSE
# True
# data id  KORA
# ['/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/volume/KORA2453666.nii.gz', '/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/dataset/KORA/test/label9/KORA2453666.nii.gz']

# %%
model_path = "/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/experiments/pp2_axial_kora_do_cw_swa_CSSE_seed_transform_octave_inn_concat2/checkpoints/*"
chkpts = glob.glob(model_path)
ch = chkpts[200]
try: 
    settings = Settings('/home/abhijit/Jyotirmay/abdominal_segmentation/quickNAT_pytorch/settings_merged_jj.ini')
    common_params, data_params, net_params, train_params, eval_params = settings['COMMON'], settings['DATA'], \
                                                                    settings[
                                                                        'NETWORK'], settings['TRAINING'], \
                                                                    settings['EVAL']
    evaluate_save_best(eval_params, net_params, data_params, common_params, train_params, ch)
except Exception as e:
    print(e)

# %%
74.88857, 31
77.898, 75.224966, 36
78.504807, 75.90687, 60
78.71778,  76.13684, 257

# %%
71, 26
71.24, 41
71.96, 43
72.17, 44
73.4,  52
74.1,  201  76.9058
74.05, 299  76.86589
