# %%
import glob
import os

# %%
dirs = os.listdir("/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/temp2/UKB/n4_corrected_2/vol/")
print(dirs[:5])
tot = len(dirs)
f_c = []
for idx, di in enumerate(dirs):
    ac = glob.glob(f"/mnt/nas/Abhijit/Jyotirmay/abdominal_segmentation/temp2/UKB/n4_corrected_2/vol/{di}/**.nii.gz")
    print(idx, tot, len(ac))
    f_c.append(len(ac))
# Out:
# ['1138634_20201_2_0', '3387088_20201_2_0', '1942395_20201_2_0', '1019631_20201_2_0', '5764643_20201_2_0']
# 0 12542 17
# 1 12542 17
# 2 12542 17
# 3 12542 17
# 4 12542 17
# 5 12542 17
# 6 12542 17
# 7 12542 17
# 8 12542 17
# 9 12542 17
# 10 12542 17
# 11 12542 17
# 12 12542 17
# 13 12542 17
# 14 12542 17
# 15 12542 17
# 16 12542 17
# 17 12542 17
# 18 12542 17
# 19 12542 17
# 20 12542 9
# 21 12542 17
# 22 12542 17
# 23 12542 17
# 24 12542 17
# 25 12542 17
# 26 12542 17
# 27 12542 17
# 28 12542 17
# 29 12542 17
# 30 12542 17
# 31 12542 17
# 32 12542 17
# 33 12542 17
# 34 12542 17
# 35 12542 17
# 36 12542 17
# 37 12542 17
# 38 12542 17
# 39 12542 17
# 40 12542 17
# 41 12542 17
# 42 12542 17
# 43 12542 17
# 44 12542 17
# 45 12542 17
# 46 12542 17
# 47 12542 17
# 48 12542 17
# 49 12542 17
# 50 12542 17
# 51 12542 17
# 52 12542 17
# 53 12542 17
# 54 12542 17
# 55 12542 17
# 56 12542 17
# 57 12542 17
# 58 12542 17
# 59 12542 17
# 60 12542 17
# 61 12542 17
# 62 12542 17
# 63 12542 17
# ...

# %%
import numpy as np

# %%
f_c = np.array(f_c)
abc = f_c[f_c == 17]
print(abc, len(abc))
# Out:
# [17 17 17 ... 17 17 17] 6265

# %%
np.unique(f_c)

# %%
import json
import telegram
bot = telegram.Bot(token='1545478723:AAEwxQyTpOzLcYGUUMDL5_v5eBRRojchAow')

def telegram_notifier(message):
    bot.sendMessage(chat_id='1139436524', text=str(message))
